# %%
import pandas as pd
import numpy as np

# Load the preprocessed data
modelling_table = pd.read_csv("analyzed_data.csv")

modelling_table['valid_datetime'] = pd.to_datetime(modelling_table['valid_datetime'])
modelling_table['ref_datetime'] = pd.to_datetime(modelling_table['ref_datetime'])

# Define the Pinball function
def pinball(y, q, alpha):
    return round((y - q) * alpha * (y >= q) + (q - y) * (1 - alpha) * (y < q),2)

# Calculate the Pinball Score
def pinball_score(df):
    score = list()
    for qu in range(10, 100, 10):
        pinball_loss = pinball(y=df["total_generation_MWh"], q=df[f"q{qu}"], alpha=qu/100).mean()
        rounded_loss = round(pinball_loss, 2)
        score.append(rounded_loss)
        print(f"pinball loss for q{qu} = {rounded_loss:.2f}")  # Use formatted string with .2f
    return round(sum(score)/len(score), 2)

# Calculate and print the Pinball Score
score = pinball_score(modelling_table)
print(f"pinball loss = {score:.2f}")  # Use formatted string with .2f
# Out:
# pinball loss for q10 = 17.55
# pinball loss for q20 = 26.12
# pinball loss for q30 = 31.39
# pinball loss for q40 = 34.29
# pinball loss for q50 = 35.11
# pinball loss for q60 = 33.94
# pinball loss for q70 = 30.73
# pinball loss for q80 = 25.15
# pinball loss for q90 = 16.38
# pinball loss = 27.85

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# 特定のref_datetimeに一致する行を抽出
ref_datetime = pd.to_datetime("2021-6-1 00:00:00+0000")
filtered_data = modelling_table[modelling_table['ref_datetime'] == ref_datetime]

plt.figure(figsize=(10, 6))
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
ax1 = sns.lineplot(data=filtered_data, x="valid_datetime", y="total_generation_MWh", label="True")

for quantile in range(10, 100, 10):
    sns.lineplot(data=modelling_table,
                 x=filtered_data["valid_datetime"],
                 y=filtered_data[f"q{quantile}"],
                 color='gray',
                 alpha=1 - abs(50 - quantile) / 50,
                 label=f'q{quantile}')

plt.ylim(0, 1400)
plt.xlim(filtered_data['valid_datetime'].min(), filtered_data['valid_datetime'].max())
#plt.xticks(modelling_table['valid_datetime'][::6])
ax1.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M \n%m/%d"))
plt.xlabel('Date/Time [30-minute period]', fontsize=20)
plt.ylabel('Total generation [MWh]', fontsize=20)
#plt.title(f"Forecast reference time: {filtered_data['ref_datetime'].iloc[0]}", fontsize=14)
plt.tight_layout()
ax1.legend(fontsize=16)
plt.tick_params(axis='both', labelsize=16)

plt.show()

# %%
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

modelling_table['lead_time'] = modelling_table['valid_datetime'] - modelling_table['ref_datetime']

forecast_performance = modelling_table.groupby('lead_time').apply(pinball_score)
forecast_performance = modelling_table.groupby('lead_time').apply(pinball_score)
forecast_performance.index = forecast_performance.index.total_seconds() / (3600)

plt.figure(figsize=(10, 6))
ax1 = forecast_performance.plot()
ax1.set_ylabel('Pinball Score [MWh]')
ax1.set_xlabel('Forecast Lead-time [30-minute period]', fontsize=12)

# x軸の刻みを変更
ax1.xaxis.set_major_locator(ticker.MultipleLocator(base=3))  # 6は3時間ごとに調整したい場合

ax1.set_title('Forecast Degradation', loc='left')
plt.tight_layout()
# Out:
# pinball loss for q10 = 15.23
# pinball loss for q20 = 22.73
# pinball loss for q30 = 27.27
# pinball loss for q40 = 29.72
# pinball loss for q50 = 30.15
# pinball loss for q60 = 28.99
# pinball loss for q70 = 26.18
# pinball loss for q80 = 21.25
# pinball loss for q90 = 13.66
# pinball loss for q10 = 15.11
# pinball loss for q20 = 22.55
# pinball loss for q30 = 27.09
# pinball loss for q40 = 29.57
# pinball loss for q50 = 30.22
# pinball loss for q60 = 29.06
# pinball loss for q70 = 26.13
# pinball loss for q80 = 21.23
# pinball loss for q90 = 13.81
# pinball loss for q10 = 14.76
# pinball loss for q20 = 21.78
# pinball loss for q30 = 26.13
# pinball loss for q40 = 28.61
# pinball loss for q50 = 29.30
# pinball loss for q60 = 28.27
# pinball loss for q70 = 25.39
# pinball loss for q80 = 20.69
# pinball loss for q90 = 13.53
# pinball loss for q10 = 14.64
# pinball loss for q20 = 21.29
# pinball loss for q30 = 25.34
# pinball loss for q40 = 27.62
# pinball loss for q50 = 28.34
# pinball loss for q60 = 27.44
# pinball loss for q70 = 24.71
# pinball loss for q80 = 20.31
# pinball loss for q90 = 13.41
# pinball loss for q10 = 14.71
# pinball loss for q20 = 21.22
# pinball loss for q30 = 25.13
# pinball loss for q40 = 27.11
# pinball loss for q50 = 27.54
# pinball loss for q60 = 26.44
# pinball loss for q70 = 23.84
# pinball loss for q80 = 19.68
# pinball loss for q90 = 13.12
# pinball loss for q10 = 15.02
# pinball loss for q20 = 21.61
# pinball loss for q30 = 25.45
# pinball loss for q40 = 27.24
# pinball loss for q50 = 27.30
# pinball loss for q60 = 26.06
# pinball loss for q70 = 23.41
# pinball loss for q80 = 19.21
# pinball loss for q90 = 12.78
# pinball loss for q10 = 15.11
# pinball loss for q20 = 21.89
# pinball loss for q30 = 25.86
# pinball loss for q40 = 27.61
# pinball loss for q50 = 27.67
# pinball loss for q60 = 26.24
# pinball loss for q70 = 23.43
# pinball loss for q80 = 19.21
# pinball loss for q90 = 12.62
# pinball loss for q10 = 14.92
# pinball loss for q20 = 21.81
# pinball loss for q30 = 25.82
# pinball loss for q40 = 27.86
# pinball loss for q50 = 28.09
# pinball loss for q60 = 26.73
# pinball loss for q70 = 24.04
# pinball loss for q80 = 19.65
# pinball loss for q90 = 12.79
# pinball loss for q10 = 14.76
# pinball loss for q20 = 21.67
# pinball loss for q30 = 25.87
# pinball loss for q40 = 28.16
# pinball loss for q50 = 28.62
# pinball loss for q60 = 27.55
# pinball loss for q70 = 24.96
# pinball loss for q80 = 20.37
# pinball loss for q90 = 13.16
# pinball loss for q10 = 14.55
# pinball loss for q20 = 21.52
# pinball loss for q30 = 25.86
# pinball loss for q40 = 28.28
# pinball loss for q50 = 28.95
# pinball loss for q60 = 28.18
# pinball loss for q70 = 25.62
# pinball loss for q80 = 21.03
# pinball loss for q90 = 13.67
# pinball loss for q10 = 14.86
# pinball loss for q20 = 22.04
# pinball loss for q30 = 26.64
# pinball loss for q40 = 29.18
# pinball loss for q50 = 29.98
# pinball loss for q60 = 29.19
# pinball loss for q70 = 26.67
# pinball loss for q80 = 21.83
# pinball loss for q90 = 14.19
# pinball loss for q10 = 15.24
# pinball loss for q20 = 22.70
# pinball loss for q30 = 27.36
# pinball loss for q40 = 30.01
# pinball loss for q50 = 30.87
# pinball loss for q60 = 30.06
# pinball loss for q70 = 27.40
# pinball loss for q80 = 22.38
# pinball loss for q90 = 14.42
# pinball loss for q10 = 15.49
# pinball loss for q20 = 23.19
# pinball loss for q30 = 27.96
# pinball loss for q40 = 30.62
# pinball loss for q50 = 31.30
# pinball loss for q60 = 30.29
# pinball loss for q70 = 27.43
# pinball loss for q80 = 22.31
# pinball loss for q90 = 14.30
# pinball loss for q10 = 15.52
# pinball loss for q20 = 23.29
# pinball loss for q30 = 28.16
# pinball loss for q40 = 30.88
# pinball loss for q50 = 31.67
# pinball loss for q60 = 30.72
# pinball loss for q70 = 27.77
# pinball loss for q80 = 22.59
# pinball loss for q90 = 14.51
# pinball loss for q10 = 15.30
# pinball loss for q20 = 22.67
# pinball loss for q30 = 27.40
# pinball loss for q40 = 30.18
# pinball loss for q50 = 31.11
# pinball loss for q60 = 30.19
# pinball loss for q70 = 27.31
# pinball loss for q80 = 22.13
# pinball loss for q90 = 14.22
# pinball loss for q10 = 15.13
# pinball loss for q20 = 22.19
# pinball loss for q30 = 26.64
# pinball loss for q40 = 29.25
# pinball loss for q50 = 30.17
# pinball loss for q60 = 29.34
# pinball loss for q70 = 26.57
# pinball loss for q80 = 21.64
# pinball loss for q90 = 14.03
# pinball loss for q10 = 15.23
# pinball loss for q20 = 22.19
# pinball loss for q30 = 26.38
# pinball loss for q40 = 28.61
# pinball loss for q50 = 29.16
# pinball loss for q60 = 28.15
# pinball loss for q70 = 25.47
# pinball loss for q80 = 20.93
# pinball loss for q90 = 13.77
# pinball loss for q10 = 15.48
# pinball loss for q20 = 22.44
# pinball loss for q30 = 26.51
# pinball loss for q40 = 28.53
# pinball loss for q50 = 28.79
# pinball loss for q60 = 27.59
# pinball loss for q70 = 24.73
# pinball loss for q80 = 20.22
# pinball loss for q90 = 13.35
# pinball loss for q10 = 15.60
# pinball loss for q20 = 22.61
# pinball loss for q30 = 26.92
# pinball loss for q40 = 28.88
# pinball loss for q50 = 29.15
# pinball loss for q60 = 27.76
# pinball loss for q70 = 24.78
# pinball loss for q80 = 20.23
# pinball loss for q90 = 13.24
# pinball loss for q10 = 15.40
# pinball loss for q20 = 22.62
# pinball loss for q30 = 26.91
# pinball loss for q40 = 29.12
# pinball loss for q50 = 29.41
# pinball loss for q60 = 28.04
# pinball loss for q70 = 25.19
# pinball loss for q80 = 20.52
# pinball loss for q90 = 13.37
# pinball loss for q10 = 15.33
# pinball loss for q20 = 22.63
# pinball loss for q30 = 27.14
# pinball loss for q40 = 29.50
# pinball loss for q50 = 30.01
# pinball loss for q60 = 28.78
# pinball loss for q70 = 25.95
# pinball loss for q80 = 21.16
# pinball loss for q90 = 13.63
# pinball loss for q10 = 15.07
# pinball loss for q20 = 22.42
# pinball loss for q30 = 26.95
# pinball loss for q40 = 29.38
# pinball loss for q50 = 30.05
# pinball loss for q60 = 29.08
# pinball loss for q70 = 26.49
# pinball loss for q80 = 21.82
# pinball loss for q90 = 14.19
# pinball loss for q10 = 15.29
# pinball loss for q20 = 22.98
# pinball loss for q30 = 27.69
# pinball loss for q40 = 30.36
# pinball loss for q50 = 31.18
# pinball loss for q60 = 30.28
# pinball loss for q70 = 27.54
# pinball loss for q80 = 22.55
# pinball loss for q90 = 14.69
# pinball loss for q10 = 15.63
# pinball loss for q20 = 23.63
# pinball loss for q30 = 28.58
# pinball loss for q40 = 31.29
# pinball loss for q50 = 32.16
# pinball loss for q60 = 31.26
# pinball loss for q70 = 28.38
# pinball loss for q80 = 23.15
# pinball loss for q90 = 14.93
# pinball loss for q10 = 16.14
# pinball loss for q20 = 24.19
# pinball loss for q30 = 29.17
# pinball loss for q40 = 32.02
# pinball loss for q50 = 32.82
# pinball loss for q60 = 31.79
# pinball loss for q70 = 28.74
# pinball loss for q80 = 23.29
# pinball loss for q90 = 14.97
# pinball loss for q10 = 16.14
# pinball loss for q20 = 24.31
# pinball loss for q30 = 29.25
# pinball loss for q40 = 32.08
# pinball loss for q50 = 33.02
# pinball loss for q60 = 32.12
# pinball loss for q70 = 29.15
# pinball loss for q80 = 23.79
# pinball loss for q90 = 15.18
# pinball loss for q10 = 15.81
# pinball loss for q20 = 23.60
# pinball loss for q30 = 28.42
# pinball loss for q40 = 31.25
# pinball loss for q50 = 32.24
# pinball loss for q60 = 31.32
# pinball loss for q70 = 28.39
# pinball loss for q80 = 23.12
# pinball loss for q90 = 14.82
# pinball loss for q10 = 15.59
# pinball loss for q20 = 22.96
# pinball loss for q30 = 27.61
# pinball loss for q40 = 30.33
# pinball loss for q50 = 31.35
# pinball loss for q60 = 30.55
# pinball loss for q70 = 27.68
# pinball loss for q80 = 22.62
# pinball loss for q90 = 14.66
# pinball loss for q10 = 15.73
# pinball loss for q20 = 23.16
# pinball loss for q30 = 27.63
# pinball loss for q40 = 30.17
# pinball loss for q50 = 30.90
# pinball loss for q60 = 29.77
# pinball loss for q70 = 26.85
# pinball loss for q80 = 21.98
# pinball loss for q90 = 14.30
# pinball loss for q10 = 16.16
# pinball loss for q20 = 23.62
# pinball loss for q30 = 28.02
# pinball loss for q40 = 30.25
# pinball loss for q50 = 30.71
# pinball loss for q60 = 29.38
# pinball loss for q70 = 26.24
# pinball loss for q80 = 21.27
# pinball loss for q90 = 13.96
# pinball loss for q10 = 16.42
# pinball loss for q20 = 24.04
# pinball loss for q30 = 28.52
# pinball loss for q40 = 30.72
# pinball loss for q50 = 30.93
# pinball loss for q60 = 29.52
# pinball loss for q70 = 26.39
# pinball loss for q80 = 21.36
# pinball loss for q90 = 13.92
# pinball loss for q10 = 16.26
# pinball loss for q20 = 23.99
# pinball loss for q30 = 28.70
# pinball loss for q40 = 30.99
# pinball loss for q50 = 31.33
# pinball loss for q60 = 29.91
# pinball loss for q70 = 26.90
# pinball loss for q80 = 21.79
# pinball loss for q90 = 14.16
# pinball loss for q10 = 16.34
# pinball loss for q20 = 24.17
# pinball loss for q30 = 29.04
# pinball loss for q40 = 31.60
# pinball loss for q50 = 32.24
# pinball loss for q60 = 30.93
# pinball loss for q70 = 27.83
# pinball loss for q80 = 22.65
# pinball loss for q90 = 14.56
# pinball loss for q10 = 16.10
# pinball loss for q20 = 23.96
# pinball loss for q30 = 28.90
# pinball loss for q40 = 31.64
# pinball loss for q50 = 32.40
# pinball loss for q60 = 31.42
# pinball loss for q70 = 28.50
# pinball loss for q80 = 23.31
# pinball loss for q90 = 15.07
# pinball loss for q10 = 16.26
# pinball loss for q20 = 24.55
# pinball loss for q30 = 29.71
# pinball loss for q40 = 32.70
# pinball loss for q50 = 33.63
# pinball loss for q60 = 32.68
# pinball loss for q70 = 29.64
# pinball loss for q80 = 24.11
# pinball loss for q90 = 15.51
# pinball loss for q10 = 16.74
# pinball loss for q20 = 25.17
# pinball loss for q30 = 30.40
# pinball loss for q40 = 33.36
# pinball loss for q50 = 34.43
# pinball loss for q60 = 33.52
# pinball loss for q70 = 30.42
# pinball loss for q80 = 24.75
# pinball loss for q90 = 15.86
# pinball loss for q10 = 17.23
# pinball loss for q20 = 25.83
# pinball loss for q30 = 31.12
# pinball loss for q40 = 34.02
# pinball loss for q50 = 34.85
# pinball loss for q60 = 33.79
# pinball loss for q70 = 30.59
# pinball loss for q80 = 24.82
# pinball loss for q90 = 15.79
# pinball loss for q10 = 17.13
# pinball loss for q20 = 25.83
# pinball loss for q30 = 31.20
# pinball loss for q40 = 34.15
# pinball loss for q50 = 35.13
# pinball loss for q60 = 34.11
# pinball loss for q70 = 30.88
# pinball loss for q80 = 25.06
# pinball loss for q90 = 15.94
# pinball loss for q10 = 16.75
# pinball loss for q20 = 25.10
# pinball loss for q30 = 30.28
# pinball loss for q40 = 33.21
# pinball loss for q50 = 34.23
# pinball loss for q60 = 33.24
# pinball loss for q70 = 30.07
# pinball loss for q80 = 24.41
# pinball loss for q90 = 15.56
# pinball loss for q10 = 16.49
# pinball loss for q20 = 24.51
# pinball loss for q30 = 29.50
# pinball loss for q40 = 32.39
# pinball loss for q50 = 33.50
# pinball loss for q60 = 32.47
# pinball loss for q70 = 29.43
# pinball loss for q80 = 23.86
# pinball loss for q90 = 15.24
# pinball loss for q10 = 16.57
# pinball loss for q20 = 24.55
# pinball loss for q30 = 29.48
# pinball loss for q40 = 32.17
# pinball loss for q50 = 32.97
# pinball loss for q60 = 31.85
# pinball loss for q70 = 28.73
# pinball loss for q80 = 23.35
# pinball loss for q90 = 15.02
# pinball loss for q10 = 16.76
# pinball loss for q20 = 24.74
# pinball loss for q30 = 29.53
# pinball loss for q40 = 32.08
# pinball loss for q50 = 32.69
# pinball loss for q60 = 31.50
# pinball loss for q70 = 28.31
# pinball loss for q80 = 22.91
# pinball loss for q90 = 14.76
# pinball loss for q10 = 16.86
# pinball loss for q20 = 25.06
# pinball loss for q30 = 30.08
# pinball loss for q40 = 32.55
# pinball loss for q50 = 32.98
# pinball loss for q60 = 31.62
# pinball loss for q70 = 28.30
# pinball loss for q80 = 22.99
# pinball loss for q90 = 14.97
# pinball loss for q10 = 16.70
# pinball loss for q20 = 24.89
# pinball loss for q30 = 29.92
# pinball loss for q40 = 32.59
# pinball loss for q50 = 33.12
# pinball loss for q60 = 31.75
# pinball loss for q70 = 28.56
# pinball loss for q80 = 23.33
# pinball loss for q90 = 15.10
# pinball loss for q10 = 16.70
# pinball loss for q20 = 24.95
# pinball loss for q30 = 30.11
# pinball loss for q40 = 33.04
# pinball loss for q50 = 33.78
# pinball loss for q60 = 32.52
# pinball loss for q70 = 29.42
# pinball loss for q80 = 24.15
# pinball loss for q90 = 15.66
# pinball loss for q10 = 16.67
# pinball loss for q20 = 25.05
# pinball loss for q30 = 30.28
# pinball loss for q40 = 33.25
# pinball loss for q50 = 34.19
# pinball loss for q60 = 33.22
# pinball loss for q70 = 30.15
# pinball loss for q80 = 24.69
# pinball loss for q90 = 16.08
# pinball loss for q10 = 16.98
# pinball loss for q20 = 25.70
# pinball loss for q30 = 31.32
# pinball loss for q40 = 34.50
# pinball loss for q50 = 35.46
# pinball loss for q60 = 34.32
# pinball loss for q70 = 30.98
# pinball loss for q80 = 25.31
# pinball loss for q90 = 16.50
# pinball loss for q10 = 17.39
# pinball loss for q20 = 26.23
# pinball loss for q30 = 31.86
# pinball loss for q40 = 35.04
# pinball loss for q50 = 36.05
# pinball loss for q60 = 35.02
# pinball loss for q70 = 31.78
# pinball loss for q80 = 25.92
# pinball loss for q90 = 16.84
# pinball loss for q10 = 17.87
# pinball loss for q20 = 26.85
# pinball loss for q30 = 32.49
# pinball loss for q40 = 35.69
# pinball loss for q50 = 36.73
# pinball loss for q60 = 35.62
# pinball loss for q70 = 32.26
# pinball loss for q80 = 26.30
# pinball loss for q90 = 17.05
# pinball loss for q10 = 17.71
# pinball loss for q20 = 26.88
# pinball loss for q30 = 32.61
# pinball loss for q40 = 35.90
# pinball loss for q50 = 37.00
# pinball loss for q60 = 35.92
# pinball loss for q70 = 32.64
# pinball loss for q80 = 26.71
# pinball loss for q90 = 17.25
# pinball loss for q10 = 17.29
# pinball loss for q20 = 26.17
# pinball loss for q30 = 31.79
# pinball loss for q40 = 35.02
# pinball loss for q50 = 36.16
# pinball loss for q60 = 35.10
# pinball loss for q70 = 31.74
# pinball loss for q80 = 25.93
# pinball loss for q90 = 16.71
# pinball loss for q10 = 17.03
# pinball loss for q20 = 25.60
# pinball loss for q30 = 31.01
# pinball loss for q40 = 34.18
# pinball loss for q50 = 35.30
# pinball loss for q60 = 34.23
# pinball loss for q70 = 31.02
# pinball loss for q80 = 25.28
# pinball loss for q90 = 16.34
# pinball loss for q10 = 17.23
# pinball loss for q20 = 25.65
# pinball loss for q30 = 30.88
# pinball loss for q40 = 33.79
# pinball loss for q50 = 34.66
# pinball loss for q60 = 33.50
# pinball loss for q70 = 30.26
# pinball loss for q80 = 24.80
# pinball loss for q90 = 16.07
# pinball loss for q10 = 17.43
# pinball loss for q20 = 25.87
# pinball loss for q30 = 31.00
# pinball loss for q40 = 33.76
# pinball loss for q50 = 34.51
# pinball loss for q60 = 33.12
# pinball loss for q70 = 29.84
# pinball loss for q80 = 24.25
# pinball loss for q90 = 15.64
# pinball loss for q10 = 17.81
# pinball loss for q20 = 26.40
# pinball loss for q30 = 31.39
# pinball loss for q40 = 33.95
# pinball loss for q50 = 34.54
# pinball loss for q60 = 33.19
# pinball loss for q70 = 29.77
# pinball loss for q80 = 24.12
# pinball loss for q90 = 15.50
# pinball loss for q10 = 17.64
# pinball loss for q20 = 26.31
# pinball loss for q30 = 31.39
# pinball loss for q40 = 33.99
# pinball loss for q50 = 34.60
# pinball loss for q60 = 33.22
# pinball loss for q70 = 29.97
# pinball loss for q80 = 24.44
# pinball loss for q90 = 15.75
# pinball loss for q10 = 17.62
# pinball loss for q20 = 26.34
# pinball loss for q30 = 31.62
# pinball loss for q40 = 34.50
# pinball loss for q50 = 35.22
# pinball loss for q60 = 33.94
# pinball loss for q70 = 30.68
# pinball loss for q80 = 25.05
# pinball loss for q90 = 16.16
# pinball loss for q10 = 17.71
# pinball loss for q20 = 26.55
# pinball loss for q30 = 31.99
# pinball loss for q40 = 35.01
# pinball loss for q50 = 35.86
# pinball loss for q60 = 34.72
# pinball loss for q70 = 31.49
# pinball loss for q80 = 25.80
# pinball loss for q90 = 16.73
# pinball loss for q10 = 18.22
# pinball loss for q20 = 27.32
# pinball loss for q30 = 33.03
# pinball loss for q40 = 36.20
# pinball loss for q50 = 37.11
# pinball loss for q60 = 35.94
# pinball loss for q70 = 32.47
# pinball loss for q80 = 26.46
# pinball loss for q90 = 17.20
# pinball loss for q10 = 18.61
# pinball loss for q20 = 27.84
# pinball loss for q30 = 33.61
# pinball loss for q40 = 36.76
# pinball loss for q50 = 37.74
# pinball loss for q60 = 36.65
# pinball loss for q70 = 33.27
# pinball loss for q80 = 27.13
# pinball loss for q90 = 17.69
# pinball loss for q10 = 18.95
# pinball loss for q20 = 28.39
# pinball loss for q30 = 34.29
# pinball loss for q40 = 37.52
# pinball loss for q50 = 38.52
# pinball loss for q60 = 37.35
# pinball loss for q70 = 33.84
# pinball loss for q80 = 27.66
# pinball loss for q90 = 17.95
# pinball loss for q10 = 18.63
# pinball loss for q20 = 28.04
# pinball loss for q30 = 34.02
# pinball loss for q40 = 37.48
# pinball loss for q50 = 38.60
# pinball loss for q60 = 37.51
# pinball loss for q70 = 34.11
# pinball loss for q80 = 27.93
# pinball loss for q90 = 18.07
# pinball loss for q10 = 18.14
# pinball loss for q20 = 27.27
# pinball loss for q30 = 33.08
# pinball loss for q40 = 36.57
# pinball loss for q50 = 37.72
# pinball loss for q60 = 36.62
# pinball loss for q70 = 33.29
# pinball loss for q80 = 27.23
# pinball loss for q90 = 17.62
# pinball loss for q10 = 17.87
# pinball loss for q20 = 26.72
# pinball loss for q30 = 32.44
# pinball loss for q40 = 35.76
# pinball loss for q50 = 36.81
# pinball loss for q60 = 35.68
# pinball loss for q70 = 32.36
# pinball loss for q80 = 26.41
# pinball loss for q90 = 17.21
# pinball loss for q10 = 18.01
# pinball loss for q20 = 26.90
# pinball loss for q30 = 32.34
# pinball loss for q40 = 35.38
# pinball loss for q50 = 36.26
# pinball loss for q60 = 35.03
# pinball loss for q70 = 31.64
# pinball loss for q80 = 25.88
# pinball loss for q90 = 16.94
# pinball loss for q10 = 18.18
# pinball loss for q20 = 27.03
# pinball loss for q30 = 32.36
# pinball loss for q40 = 35.23
# pinball loss for q50 = 35.99
# pinball loss for q60 = 34.67
# pinball loss for q70 = 31.22
# pinball loss for q80 = 25.52
# pinball loss for q90 = 16.69
# pinball loss for q10 = 18.49
# pinball loss for q20 = 27.61
# pinball loss for q30 = 32.91
# pinball loss for q40 = 35.70
# pinball loss for q50 = 36.34
# pinball loss for q60 = 34.87
# pinball loss for q70 = 31.39
# pinball loss for q80 = 25.63
# pinball loss for q90 = 16.79
# pinball loss for q10 = 18.42
# pinball loss for q20 = 27.53
# pinball loss for q30 = 33.00
# pinball loss for q40 = 35.95
# pinball loss for q50 = 36.67
# pinball loss for q60 = 35.26
# pinball loss for q70 = 31.86
# pinball loss for q80 = 26.13
# pinball loss for q90 = 17.16
# pinball loss for q10 = 18.55
# pinball loss for q20 = 27.76
# pinball loss for q30 = 33.35
# pinball loss for q40 = 36.41
# pinball loss for q50 = 37.32
# pinball loss for q60 = 36.11
# pinball loss for q70 = 32.69
# pinball loss for q80 = 26.84
# pinball loss for q90 = 17.43
# pinball loss for q10 = 18.67
# pinball loss for q20 = 28.00
# pinball loss for q30 = 33.69
# pinball loss for q40 = 36.82
# pinball loss for q50 = 37.79
# pinball loss for q60 = 36.66
# pinball loss for q70 = 33.30
# pinball loss for q80 = 27.43
# pinball loss for q90 = 17.95
# pinball loss for q10 = 19.10
# pinball loss for q20 = 28.71
# pinball loss for q30 = 34.66
# pinball loss for q40 = 37.95
# pinball loss for q50 = 38.99
# pinball loss for q60 = 37.83
# pinball loss for q70 = 34.39
# pinball loss for q80 = 28.30
# pinball loss for q90 = 18.52
# pinball loss for q10 = 19.36
# pinball loss for q20 = 29.15
# pinball loss for q30 = 35.26
# pinball loss for q40 = 38.66
# pinball loss for q50 = 39.66
# pinball loss for q60 = 38.44
# pinball loss for q70 = 34.87
# pinball loss for q80 = 28.63
# pinball loss for q90 = 18.77
# pinball loss for q10 = 20.01
# pinball loss for q20 = 29.93
# pinball loss for q30 = 36.03
# pinball loss for q40 = 39.41
# pinball loss for q50 = 40.36
# pinball loss for q60 = 39.09
# pinball loss for q70 = 35.47
# pinball loss for q80 = 29.02
# pinball loss for q90 = 18.84
# pinball loss for q10 = 19.55
# pinball loss for q20 = 29.50
# pinball loss for q30 = 35.68
# pinball loss for q40 = 39.26
# pinball loss for q50 = 40.46
# pinball loss for q60 = 39.23
# pinball loss for q70 = 35.65
# pinball loss for q80 = 29.24
# pinball loss for q90 = 18.98
# pinball loss for q10 = 19.20
# pinball loss for q20 = 28.86
# pinball loss for q30 = 34.97
# pinball loss for q40 = 38.60
# pinball loss for q50 = 39.67
# pinball loss for q60 = 38.40
# pinball loss for q70 = 34.85
# pinball loss for q80 = 28.56
# pinball loss for q90 = 18.50
# pinball loss for q10 = 19.06
# pinball loss for q20 = 28.43
# pinball loss for q30 = 34.31
# pinball loss for q40 = 37.68
# pinball loss for q50 = 38.81
# pinball loss for q60 = 37.63
# pinball loss for q70 = 34.07
# pinball loss for q80 = 27.83
# pinball loss for q90 = 17.99
# pinball loss for q10 = 19.34
# pinball loss for q20 = 28.79
# pinball loss for q30 = 34.40
# pinball loss for q40 = 37.45
# pinball loss for q50 = 38.33
# pinball loss for q60 = 37.10
# pinball loss for q70 = 33.46
# pinball loss for q80 = 27.34
# pinball loss for q90 = 17.67
# pinball loss for q10 = 19.68
# pinball loss for q20 = 29.07
# pinball loss for q30 = 34.70
# pinball loss for q40 = 37.66
# pinball loss for q50 = 38.37
# pinball loss for q60 = 36.92
# pinball loss for q70 = 33.25
# pinball loss for q80 = 27.08
# pinball loss for q90 = 17.53
# pinball loss for q10 = 20.06
# pinball loss for q20 = 29.66
# pinball loss for q30 = 35.32
# pinball loss for q40 = 38.14
# pinball loss for q50 = 38.70
# pinball loss for q60 = 37.19
# pinball loss for q70 = 33.44
# pinball loss for q80 = 27.25
# pinball loss for q90 = 17.86
# pinball loss for q10 = 19.89
# pinball loss for q20 = 29.62
# pinball loss for q30 = 35.47
# pinball loss for q40 = 38.52
# pinball loss for q50 = 39.21
# pinball loss for q60 = 37.73
# pinball loss for q70 = 34.19
# pinball loss for q80 = 28.13
# pinball loss for q90 = 18.67
# pinball loss for q10 = 19.93
# pinball loss for q20 = 29.55
# pinball loss for q30 = 35.52
# pinball loss for q40 = 38.73
# pinball loss for q50 = 39.65
# pinball loss for q60 = 38.39
# pinball loss for q70 = 34.97
# pinball loss for q80 = 28.87
# pinball loss for q90 = 19.10
# pinball loss for q10 = 19.79
# pinball loss for q20 = 29.64
# pinball loss for q30 = 35.64
# pinball loss for q40 = 38.95
# pinball loss for q50 = 39.98
# pinball loss for q60 = 38.89
# pinball loss for q70 = 35.49
# pinball loss for q80 = 29.38
# pinball loss for q90 = 19.46
# pinball loss for q10 = 20.33
# pinball loss for q20 = 30.53
# pinball loss for q30 = 36.73
# pinball loss for q40 = 40.17
# pinball loss for q50 = 41.30
# pinball loss for q60 = 40.03
# pinball loss for q70 = 36.39
# pinball loss for q80 = 30.00
# pinball loss for q90 = 19.90
# pinball loss for q10 = 20.52
# pinball loss for q20 = 30.78
# pinball loss for q30 = 37.25
# pinball loss for q40 = 40.80
# pinball loss for q50 = 41.83
# pinball loss for q60 = 40.55
# pinball loss for q70 = 36.91
# pinball loss for q80 = 30.48
# pinball loss for q90 = 20.22
# pinball loss for q10 = 20.98
# pinball loss for q20 = 31.63
# pinball loss for q30 = 37.98
# pinball loss for q40 = 41.54
# pinball loss for q50 = 42.62
# pinball loss for q60 = 41.31
# pinball loss for q70 = 37.53
# pinball loss for q80 = 31.00
# pinball loss for q90 = 20.42
# pinball loss for q10 = 20.75
# pinball loss for q20 = 31.28
# pinball loss for q30 = 37.75
# pinball loss for q40 = 41.45
# pinball loss for q50 = 42.69
# pinball loss for q60 = 41.52
# pinball loss for q70 = 37.87
# pinball loss for q80 = 31.34
# pinball loss for q90 = 20.56
# pinball loss for q10 = 20.40
# pinball loss for q20 = 30.54
# pinball loss for q30 = 36.93
# pinball loss for q40 = 40.66
# pinball loss for q50 = 41.95
# pinball loss for q60 = 40.83
# pinball loss for q70 = 37.23
# pinball loss for q80 = 30.73
# pinball loss for q90 = 20.14
# pinball loss for q10 = 20.27
# pinball loss for q20 = 30.08
# pinball loss for q30 = 36.26
# pinball loss for q40 = 39.77
# pinball loss for q50 = 40.95
# pinball loss for q60 = 39.73
# pinball loss for q70 = 36.12
# pinball loss for q80 = 29.68
# pinball loss for q90 = 19.35
# pinball loss for q10 = 20.44
# pinball loss for q20 = 30.09
# pinball loss for q30 = 35.92
# pinball loss for q40 = 39.18
# pinball loss for q50 = 40.25
# pinball loss for q60 = 38.94
# pinball loss for q70 = 35.30
# pinball loss for q80 = 29.03
# pinball loss for q90 = 18.98
# pinball loss for q10 = 20.67
# pinball loss for q20 = 30.25
# pinball loss for q30 = 36.05
# pinball loss for q40 = 39.25
# pinball loss for q50 = 40.10
# pinball loss for q60 = 38.82
# pinball loss for q70 = 35.13
# pinball loss for q80 = 28.69
# pinball loss for q90 = 18.69
# pinball loss for q10 = 20.92
# pinball loss for q20 = 30.70
# pinball loss for q30 = 36.56
# pinball loss for q40 = 39.70
# pinball loss for q50 = 40.34
# pinball loss for q60 = 38.80
# pinball loss for q70 = 35.11
# pinball loss for q80 = 28.92
# pinball loss for q90 = 19.05
# pinball loss for q10 = 20.67
# pinball loss for q20 = 30.55
# pinball loss for q30 = 36.53
# pinball loss for q40 = 39.71
# pinball loss for q50 = 40.59
# pinball loss for q60 = 39.22
# pinball loss for q70 = 35.50
# pinball loss for q80 = 29.22
# pinball loss for q90 = 19.39
# pinball loss for q10 = 20.61
# pinball loss for q20 = 30.59
# pinball loss for q30 = 36.67
# pinball loss for q40 = 39.94
# pinball loss for q50 = 40.94
# pinball loss for q60 = 39.75
# pinball loss for q70 = 36.17
# pinball loss for q80 = 29.94
# pinball loss for q90 = 19.84
# pinball loss for q10 = 20.76
# pinball loss for q20 = 30.82
# pinball loss for q30 = 36.95
# pinball loss for q40 = 40.40
# pinball loss for q50 = 41.53
# pinball loss for q60 = 40.40
# pinball loss for q70 = 36.87
# pinball loss for q80 = 30.58
# pinball loss for q90 = 20.34
# pinball loss for q10 = 21.31
# pinball loss for q20 = 31.71
# pinball loss for q30 = 38.09
# pinball loss for q40 = 41.74
# pinball loss for q50 = 42.93
# pinball loss for q60 = 41.72
# pinball loss for q70 = 38.09
# pinball loss for q80 = 31.60
# pinball loss for q90 = 21.10
# pinball loss for q10 = 21.52
# pinball loss for q20 = 32.19
# pinball loss for q30 = 38.75
# pinball loss for q40 = 42.42
# pinball loss for q50 = 43.58
# pinball loss for q60 = 42.35
# pinball loss for q70 = 38.62
# pinball loss for q80 = 32.02
# pinball loss for q90 = 21.42
# pinball loss for q10 = 22.03
# pinball loss for q20 = 32.77
# pinball loss for q30 = 39.26
# pinball loss for q40 = 42.92
# pinball loss for q50 = 44.13
# pinball loss for q60 = 42.97
# pinball loss for q70 = 39.25
# pinball loss for q80 = 32.56
# pinball loss for q90 = 21.73
# pinball loss for q10 = 15.23
# pinball loss for q20 = 22.73
# pinball loss for q30 = 27.27
# pinball loss for q40 = 29.72
# pinball loss for q50 = 30.15
# pinball loss for q60 = 28.99
# pinball loss for q70 = 26.18
# pinball loss for q80 = 21.25
# pinball loss for q90 = 13.66
# pinball loss for q10 = 15.11
# pinball loss for q20 = 22.55
# pinball loss for q30 = 27.09
# pinball loss for q40 = 29.57
# pinball loss for q50 = 30.22
# pinball loss for q60 = 29.06
# pinball loss for q70 = 26.13
# pinball loss for q80 = 21.23
# pinball loss for q90 = 13.81
# pinball loss for q10 = 14.76
# pinball loss for q20 = 21.78
# pinball loss for q30 = 26.13
# pinball loss for q40 = 28.61
# pinball loss for q50 = 29.30
# pinball loss for q60 = 28.27
# pinball loss for q70 = 25.39
# pinball loss for q80 = 20.69
# pinball loss for q90 = 13.53
# pinball loss for q10 = 14.64
# pinball loss for q20 = 21.29
# pinball loss for q30 = 25.34
# pinball loss for q40 = 27.62
# pinball loss for q50 = 28.34
# pinball loss for q60 = 27.44
# pinball loss for q70 = 24.71
# pinball loss for q80 = 20.31
# pinball loss for q90 = 13.41
# pinball loss for q10 = 14.71
# pinball loss for q20 = 21.22
# pinball loss for q30 = 25.13
# pinball loss for q40 = 27.11
# pinball loss for q50 = 27.54
# pinball loss for q60 = 26.44
# pinball loss for q70 = 23.84
# pinball loss for q80 = 19.68
# pinball loss for q90 = 13.12
# pinball loss for q10 = 15.02
# pinball loss for q20 = 21.61
# pinball loss for q30 = 25.45
# pinball loss for q40 = 27.24
# pinball loss for q50 = 27.30
# pinball loss for q60 = 26.06
# pinball loss for q70 = 23.41
# pinball loss for q80 = 19.21
# pinball loss for q90 = 12.78
# pinball loss for q10 = 15.11
# pinball loss for q20 = 21.89
# pinball loss for q30 = 25.86
# pinball loss for q40 = 27.61
# pinball loss for q50 = 27.67
# pinball loss for q60 = 26.24
# pinball loss for q70 = 23.43
# pinball loss for q80 = 19.21
# pinball loss for q90 = 12.62
# pinball loss for q10 = 14.92
# pinball loss for q20 = 21.81
# pinball loss for q30 = 25.82
# pinball loss for q40 = 27.86
# pinball loss for q50 = 28.09
# pinball loss for q60 = 26.73
# pinball loss for q70 = 24.04
# pinball loss for q80 = 19.65
# pinball loss for q90 = 12.79
# pinball loss for q10 = 14.76
# pinball loss for q20 = 21.67
# pinball loss for q30 = 25.87
# pinball loss for q40 = 28.16
# pinball loss for q50 = 28.62
# pinball loss for q60 = 27.55
# pinball loss for q70 = 24.96
# pinball loss for q80 = 20.37
# pinball loss for q90 = 13.16
# pinball loss for q10 = 14.55
# pinball loss for q20 = 21.52
# pinball loss for q30 = 25.86
# pinball loss for q40 = 28.28
# pinball loss for q50 = 28.95
# pinball loss for q60 = 28.18
# pinball loss for q70 = 25.62
# pinball loss for q80 = 21.03
# pinball loss for q90 = 13.67
# pinball loss for q10 = 14.86
# pinball loss for q20 = 22.04
# pinball loss for q30 = 26.64
# pinball loss for q40 = 29.18
# pinball loss for q50 = 29.98
# pinball loss for q60 = 29.19
# pinball loss for q70 = 26.67
# pinball loss for q80 = 21.83
# pinball loss for q90 = 14.19
# pinball loss for q10 = 15.24
# pinball loss for q20 = 22.70
# pinball loss for q30 = 27.36
# pinball loss for q40 = 30.01
# pinball loss for q50 = 30.87
# pinball loss for q60 = 30.06
# pinball loss for q70 = 27.40
# pinball loss for q80 = 22.38
# pinball loss for q90 = 14.42
# pinball loss for q10 = 15.49
# pinball loss for q20 = 23.19
# pinball loss for q30 = 27.96
# pinball loss for q40 = 30.62
# pinball loss for q50 = 31.30
# pinball loss for q60 = 30.29
# pinball loss for q70 = 27.43
# pinball loss for q80 = 22.31
# pinball loss for q90 = 14.30
# pinball loss for q10 = 15.52
# pinball loss for q20 = 23.29
# pinball loss for q30 = 28.16
# pinball loss for q40 = 30.88
# pinball loss for q50 = 31.67
# pinball loss for q60 = 30.72
# pinball loss for q70 = 27.77
# pinball loss for q80 = 22.59
# pinball loss for q90 = 14.51
# pinball loss for q10 = 15.30
# pinball loss for q20 = 22.67
# pinball loss for q30 = 27.40
# pinball loss for q40 = 30.18
# pinball loss for q50 = 31.11
# pinball loss for q60 = 30.19
# pinball loss for q70 = 27.31
# pinball loss for q80 = 22.13
# pinball loss for q90 = 14.22
# pinball loss for q10 = 15.13
# pinball loss for q20 = 22.19
# pinball loss for q30 = 26.64
# pinball loss for q40 = 29.25
# pinball loss for q50 = 30.17
# pinball loss for q60 = 29.34
# pinball loss for q70 = 26.57
# pinball loss for q80 = 21.64
# pinball loss for q90 = 14.03
# pinball loss for q10 = 15.23
# pinball loss for q20 = 22.19
# pinball loss for q30 = 26.38
# pinball loss for q40 = 28.61
# pinball loss for q50 = 29.16
# pinball loss for q60 = 28.15
# pinball loss for q70 = 25.47
# pinball loss for q80 = 20.93
# pinball loss for q90 = 13.77
# pinball loss for q10 = 15.48
# pinball loss for q20 = 22.44
# pinball loss for q30 = 26.51
# pinball loss for q40 = 28.53
# pinball loss for q50 = 28.79
# pinball loss for q60 = 27.59
# pinball loss for q70 = 24.73
# pinball loss for q80 = 20.22
# pinball loss for q90 = 13.35
# pinball loss for q10 = 15.60
# pinball loss for q20 = 22.61
# pinball loss for q30 = 26.92
# pinball loss for q40 = 28.88
# pinball loss for q50 = 29.15
# pinball loss for q60 = 27.76
# pinball loss for q70 = 24.78
# pinball loss for q80 = 20.23
# pinball loss for q90 = 13.24
# pinball loss for q10 = 15.40
# pinball loss for q20 = 22.62
# pinball loss for q30 = 26.91
# pinball loss for q40 = 29.12
# pinball loss for q50 = 29.41
# pinball loss for q60 = 28.04
# pinball loss for q70 = 25.19
# pinball loss for q80 = 20.52
# pinball loss for q90 = 13.37
# pinball loss for q10 = 15.33
# pinball loss for q20 = 22.63
# pinball loss for q30 = 27.14
# pinball loss for q40 = 29.50
# pinball loss for q50 = 30.01
# pinball loss for q60 = 28.78
# pinball loss for q70 = 25.95
# pinball loss for q80 = 21.16
# pinball loss for q90 = 13.63
# pinball loss for q10 = 15.07
# pinball loss for q20 = 22.42
# pinball loss for q30 = 26.95
# pinball loss for q40 = 29.38
# pinball loss for q50 = 30.05
# pinball loss for q60 = 29.08
# pinball loss for q70 = 26.49
# pinball loss for q80 = 21.82
# pinball loss for q90 = 14.19
# pinball loss for q10 = 15.29
# pinball loss for q20 = 22.98
# pinball loss for q30 = 27.69
# pinball loss for q40 = 30.36
# pinball loss for q50 = 31.18
# pinball loss for q60 = 30.28
# pinball loss for q70 = 27.54
# pinball loss for q80 = 22.55
# pinball loss for q90 = 14.69
# pinball loss for q10 = 15.63
# pinball loss for q20 = 23.63
# pinball loss for q30 = 28.58
# pinball loss for q40 = 31.29
# pinball loss for q50 = 32.16
# pinball loss for q60 = 31.26
# pinball loss for q70 = 28.38
# pinball loss for q80 = 23.15
# pinball loss for q90 = 14.93
# pinball loss for q10 = 16.14
# pinball loss for q20 = 24.19
# pinball loss for q30 = 29.17
# pinball loss for q40 = 32.02
# pinball loss for q50 = 32.82
# pinball loss for q60 = 31.79
# pinball loss for q70 = 28.74
# pinball loss for q80 = 23.29
# pinball loss for q90 = 14.97
# pinball loss for q10 = 16.14
# pinball loss for q20 = 24.31
# pinball loss for q30 = 29.25
# pinball loss for q40 = 32.08
# pinball loss for q50 = 33.02
# pinball loss for q60 = 32.12
# pinball loss for q70 = 29.15
# pinball loss for q80 = 23.79
# pinball loss for q90 = 15.18
# pinball loss for q10 = 15.81
# pinball loss for q20 = 23.60
# pinball loss for q30 = 28.42
# pinball loss for q40 = 31.25
# pinball loss for q50 = 32.24
# pinball loss for q60 = 31.32
# pinball loss for q70 = 28.39
# pinball loss for q80 = 23.12
# pinball loss for q90 = 14.82
# pinball loss for q10 = 15.59
# pinball loss for q20 = 22.96
# pinball loss for q30 = 27.61
# pinball loss for q40 = 30.33
# pinball loss for q50 = 31.35
# pinball loss for q60 = 30.55
# pinball loss for q70 = 27.68
# pinball loss for q80 = 22.62
# pinball loss for q90 = 14.66
# pinball loss for q10 = 15.73
# pinball loss for q20 = 23.16
# pinball loss for q30 = 27.63
# pinball loss for q40 = 30.17
# pinball loss for q50 = 30.90
# pinball loss for q60 = 29.77
# pinball loss for q70 = 26.85
# pinball loss for q80 = 21.98
# pinball loss for q90 = 14.30
# pinball loss for q10 = 16.16
# pinball loss for q20 = 23.62
# pinball loss for q30 = 28.02
# pinball loss for q40 = 30.25
# pinball loss for q50 = 30.71
# pinball loss for q60 = 29.38
# pinball loss for q70 = 26.24
# pinball loss for q80 = 21.27
# pinball loss for q90 = 13.96
# pinball loss for q10 = 16.42
# pinball loss for q20 = 24.04
# pinball loss for q30 = 28.52
# pinball loss for q40 = 30.72
# pinball loss for q50 = 30.93
# pinball loss for q60 = 29.52
# pinball loss for q70 = 26.39
# pinball loss for q80 = 21.36
# pinball loss for q90 = 13.92
# pinball loss for q10 = 16.26
# pinball loss for q20 = 23.99
# pinball loss for q30 = 28.70
# pinball loss for q40 = 30.99
# pinball loss for q50 = 31.33
# pinball loss for q60 = 29.91
# pinball loss for q70 = 26.90
# pinball loss for q80 = 21.79
# pinball loss for q90 = 14.16
# pinball loss for q10 = 16.34
# pinball loss for q20 = 24.17
# pinball loss for q30 = 29.04
# pinball loss for q40 = 31.60
# pinball loss for q50 = 32.24
# pinball loss for q60 = 30.93
# pinball loss for q70 = 27.83
# pinball loss for q80 = 22.65
# pinball loss for q90 = 14.56
# pinball loss for q10 = 16.10
# pinball loss for q20 = 23.96
# pinball loss for q30 = 28.90
# pinball loss for q40 = 31.64
# pinball loss for q50 = 32.40
# pinball loss for q60 = 31.42
# pinball loss for q70 = 28.50
# pinball loss for q80 = 23.31
# pinball loss for q90 = 15.07
# pinball loss for q10 = 16.26
# pinball loss for q20 = 24.55
# pinball loss for q30 = 29.71
# pinball loss for q40 = 32.70
# pinball loss for q50 = 33.63
# pinball loss for q60 = 32.68
# pinball loss for q70 = 29.64
# pinball loss for q80 = 24.11
# pinball loss for q90 = 15.51
# pinball loss for q10 = 16.74
# pinball loss for q20 = 25.17
# pinball loss for q30 = 30.40
# pinball loss for q40 = 33.36
# pinball loss for q50 = 34.43
# pinball loss for q60 = 33.52
# pinball loss for q70 = 30.42
# pinball loss for q80 = 24.75
# pinball loss for q90 = 15.86
# pinball loss for q10 = 17.23
# pinball loss for q20 = 25.83
# pinball loss for q30 = 31.12
# pinball loss for q40 = 34.02
# pinball loss for q50 = 34.85
# pinball loss for q60 = 33.79
# pinball loss for q70 = 30.59
# pinball loss for q80 = 24.82
# pinball loss for q90 = 15.79
# pinball loss for q10 = 17.13
# pinball loss for q20 = 25.83
# pinball loss for q30 = 31.20
# pinball loss for q40 = 34.15
# pinball loss for q50 = 35.13
# pinball loss for q60 = 34.11
# pinball loss for q70 = 30.88
# pinball loss for q80 = 25.06
# pinball loss for q90 = 15.94
# pinball loss for q10 = 16.75
# pinball loss for q20 = 25.10
# pinball loss for q30 = 30.28
# pinball loss for q40 = 33.21
# pinball loss for q50 = 34.23
# pinball loss for q60 = 33.24
# pinball loss for q70 = 30.07
# pinball loss for q80 = 24.41
# pinball loss for q90 = 15.56
# pinball loss for q10 = 16.49
# pinball loss for q20 = 24.51
# pinball loss for q30 = 29.50
# pinball loss for q40 = 32.39
# pinball loss for q50 = 33.50
# pinball loss for q60 = 32.47
# pinball loss for q70 = 29.43
# pinball loss for q80 = 23.86
# pinball loss for q90 = 15.24
# pinball loss for q10 = 16.57
# pinball loss for q20 = 24.55
# pinball loss for q30 = 29.48
# pinball loss for q40 = 32.17
# pinball loss for q50 = 32.97
# pinball loss for q60 = 31.85
# pinball loss for q70 = 28.73
# pinball loss for q80 = 23.35
# pinball loss for q90 = 15.02
# pinball loss for q10 = 16.76
# pinball loss for q20 = 24.74
# pinball loss for q30 = 29.53
# pinball loss for q40 = 32.08
# pinball loss for q50 = 32.69
# pinball loss for q60 = 31.50
# pinball loss for q70 = 28.31
# pinball loss for q80 = 22.91
# pinball loss for q90 = 14.76
# pinball loss for q10 = 16.86
# pinball loss for q20 = 25.06
# pinball loss for q30 = 30.08
# pinball loss for q40 = 32.55
# pinball loss for q50 = 32.98
# pinball loss for q60 = 31.62
# pinball loss for q70 = 28.30
# pinball loss for q80 = 22.99
# pinball loss for q90 = 14.97
# pinball loss for q10 = 16.70
# pinball loss for q20 = 24.89
# pinball loss for q30 = 29.92
# pinball loss for q40 = 32.59
# pinball loss for q50 = 33.12
# pinball loss for q60 = 31.75
# pinball loss for q70 = 28.56
# pinball loss for q80 = 23.33
# pinball loss for q90 = 15.10
# pinball loss for q10 = 16.70
# pinball loss for q20 = 24.95
# pinball loss for q30 = 30.11
# pinball loss for q40 = 33.04
# pinball loss for q50 = 33.78
# pinball loss for q60 = 32.52
# pinball loss for q70 = 29.42
# pinball loss for q80 = 24.15
# pinball loss for q90 = 15.66
# pinball loss for q10 = 16.67
# pinball loss for q20 = 25.05
# pinball loss for q30 = 30.28
# pinball loss for q40 = 33.25
# pinball loss for q50 = 34.19
# pinball loss for q60 = 33.22
# pinball loss for q70 = 30.15
# pinball loss for q80 = 24.69
# pinball loss for q90 = 16.08
# pinball loss for q10 = 16.98
# pinball loss for q20 = 25.70
# pinball loss for q30 = 31.32
# pinball loss for q40 = 34.50
# pinball loss for q50 = 35.46
# pinball loss for q60 = 34.32
# pinball loss for q70 = 30.98
# pinball loss for q80 = 25.31
# pinball loss for q90 = 16.50
# pinball loss for q10 = 17.39
# pinball loss for q20 = 26.23
# pinball loss for q30 = 31.86
# pinball loss for q40 = 35.04
# pinball loss for q50 = 36.05
# pinball loss for q60 = 35.02
# pinball loss for q70 = 31.78
# pinball loss for q80 = 25.92
# pinball loss for q90 = 16.84
# pinball loss for q10 = 17.87
# pinball loss for q20 = 26.85
# pinball loss for q30 = 32.49
# pinball loss for q40 = 35.69
# pinball loss for q50 = 36.73
# pinball loss for q60 = 35.62
# pinball loss for q70 = 32.26
# pinball loss for q80 = 26.30
# pinball loss for q90 = 17.05
# pinball loss for q10 = 17.71
# pinball loss for q20 = 26.88
# pinball loss for q30 = 32.61
# pinball loss for q40 = 35.90
# pinball loss for q50 = 37.00
# pinball loss for q60 = 35.92
# pinball loss for q70 = 32.64
# pinball loss for q80 = 26.71
# pinball loss for q90 = 17.25
# pinball loss for q10 = 17.29
# pinball loss for q20 = 26.17
# pinball loss for q30 = 31.79
# pinball loss for q40 = 35.02
# pinball loss for q50 = 36.16
# pinball loss for q60 = 35.10
# pinball loss for q70 = 31.74
# pinball loss for q80 = 25.93
# pinball loss for q90 = 16.71
# pinball loss for q10 = 17.03
# pinball loss for q20 = 25.60
# pinball loss for q30 = 31.01
# pinball loss for q40 = 34.18
# pinball loss for q50 = 35.30
# pinball loss for q60 = 34.23
# pinball loss for q70 = 31.02
# pinball loss for q80 = 25.28
# pinball loss for q90 = 16.34
# pinball loss for q10 = 17.23
# pinball loss for q20 = 25.65
# pinball loss for q30 = 30.88
# pinball loss for q40 = 33.79
# pinball loss for q50 = 34.66
# pinball loss for q60 = 33.50
# pinball loss for q70 = 30.26
# pinball loss for q80 = 24.80
# pinball loss for q90 = 16.07
# pinball loss for q10 = 17.43
# pinball loss for q20 = 25.87
# pinball loss for q30 = 31.00
# pinball loss for q40 = 33.76
# pinball loss for q50 = 34.51
# pinball loss for q60 = 33.12
# pinball loss for q70 = 29.84
# pinball loss for q80 = 24.25
# pinball loss for q90 = 15.64
# pinball loss for q10 = 17.81
# pinball loss for q20 = 26.40
# pinball loss for q30 = 31.39
# pinball loss for q40 = 33.95
# pinball loss for q50 = 34.54
# pinball loss for q60 = 33.19
# pinball loss for q70 = 29.77
# pinball loss for q80 = 24.12
# pinball loss for q90 = 15.50
# pinball loss for q10 = 17.64
# pinball loss for q20 = 26.31
# pinball loss for q30 = 31.39
# pinball loss for q40 = 33.99
# pinball loss for q50 = 34.60
# pinball loss for q60 = 33.22
# pinball loss for q70 = 29.97
# pinball loss for q80 = 24.44
# pinball loss for q90 = 15.75
# pinball loss for q10 = 17.62
# pinball loss for q20 = 26.34
# pinball loss for q30 = 31.62
# pinball loss for q40 = 34.50
# pinball loss for q50 = 35.22
# pinball loss for q60 = 33.94
# pinball loss for q70 = 30.68
# pinball loss for q80 = 25.05
# pinball loss for q90 = 16.16
# pinball loss for q10 = 17.71
# pinball loss for q20 = 26.55
# pinball loss for q30 = 31.99
# pinball loss for q40 = 35.01
# pinball loss for q50 = 35.86
# pinball loss for q60 = 34.72
# pinball loss for q70 = 31.49
# pinball loss for q80 = 25.80
# pinball loss for q90 = 16.73
# pinball loss for q10 = 18.22
# pinball loss for q20 = 27.32
# pinball loss for q30 = 33.03
# pinball loss for q40 = 36.20
# pinball loss for q50 = 37.11
# pinball loss for q60 = 35.94
# pinball loss for q70 = 32.47
# pinball loss for q80 = 26.46
# pinball loss for q90 = 17.20
# pinball loss for q10 = 18.61
# pinball loss for q20 = 27.84
# pinball loss for q30 = 33.61
# pinball loss for q40 = 36.76
# pinball loss for q50 = 37.74
# pinball loss for q60 = 36.65
# pinball loss for q70 = 33.27
# pinball loss for q80 = 27.13
# pinball loss for q90 = 17.69
# pinball loss for q10 = 18.95
# pinball loss for q20 = 28.39
# pinball loss for q30 = 34.29
# pinball loss for q40 = 37.52
# pinball loss for q50 = 38.52
# pinball loss for q60 = 37.35
# pinball loss for q70 = 33.84
# pinball loss for q80 = 27.66
# pinball loss for q90 = 17.95
# pinball loss for q10 = 18.63
# pinball loss for q20 = 28.04
# pinball loss for q30 = 34.02
# pinball loss for q40 = 37.48
# pinball loss for q50 = 38.60
# pinball loss for q60 = 37.51
# pinball loss for q70 = 34.11
# pinball loss for q80 = 27.93
# pinball loss for q90 = 18.07
# pinball loss for q10 = 18.14
# pinball loss for q20 = 27.27
# pinball loss for q30 = 33.08
# pinball loss for q40 = 36.57
# pinball loss for q50 = 37.72
# pinball loss for q60 = 36.62
# pinball loss for q70 = 33.29
# pinball loss for q80 = 27.23
# pinball loss for q90 = 17.62
# pinball loss for q10 = 17.87
# pinball loss for q20 = 26.72
# pinball loss for q30 = 32.44
# pinball loss for q40 = 35.76
# pinball loss for q50 = 36.81
# pinball loss for q60 = 35.68
# pinball loss for q70 = 32.36
# pinball loss for q80 = 26.41
# pinball loss for q90 = 17.21
# pinball loss for q10 = 18.01
# pinball loss for q20 = 26.90
# pinball loss for q30 = 32.34
# pinball loss for q40 = 35.38
# pinball loss for q50 = 36.26
# pinball loss for q60 = 35.03
# pinball loss for q70 = 31.64
# pinball loss for q80 = 25.88
# pinball loss for q90 = 16.94
# pinball loss for q10 = 18.18
# pinball loss for q20 = 27.03
# pinball loss for q30 = 32.36
# pinball loss for q40 = 35.23
# pinball loss for q50 = 35.99
# pinball loss for q60 = 34.67
# pinball loss for q70 = 31.22
# pinball loss for q80 = 25.52
# pinball loss for q90 = 16.69
# pinball loss for q10 = 18.49
# pinball loss for q20 = 27.61
# pinball loss for q30 = 32.91
# pinball loss for q40 = 35.70
# pinball loss for q50 = 36.34
# pinball loss for q60 = 34.87
# pinball loss for q70 = 31.39
# pinball loss for q80 = 25.63
# pinball loss for q90 = 16.79
# pinball loss for q10 = 18.42
# pinball loss for q20 = 27.53
# pinball loss for q30 = 33.00
# pinball loss for q40 = 35.95
# pinball loss for q50 = 36.67
# pinball loss for q60 = 35.26
# pinball loss for q70 = 31.86
# pinball loss for q80 = 26.13
# pinball loss for q90 = 17.16
# pinball loss for q10 = 18.55
# pinball loss for q20 = 27.76
# pinball loss for q30 = 33.35
# pinball loss for q40 = 36.41
# pinball loss for q50 = 37.32
# pinball loss for q60 = 36.11
# pinball loss for q70 = 32.69
# pinball loss for q80 = 26.84
# pinball loss for q90 = 17.43
# pinball loss for q10 = 18.67
# pinball loss for q20 = 28.00
# pinball loss for q30 = 33.69
# pinball loss for q40 = 36.82
# pinball loss for q50 = 37.79
# pinball loss for q60 = 36.66
# pinball loss for q70 = 33.30
# pinball loss for q80 = 27.43
# pinball loss for q90 = 17.95
# pinball loss for q10 = 19.10
# pinball loss for q20 = 28.71
# pinball loss for q30 = 34.66
# pinball loss for q40 = 37.95
# pinball loss for q50 = 38.99
# pinball loss for q60 = 37.83
# pinball loss for q70 = 34.39
# pinball loss for q80 = 28.30
# pinball loss for q90 = 18.52
# pinball loss for q10 = 19.36
# pinball loss for q20 = 29.15
# pinball loss for q30 = 35.26
# pinball loss for q40 = 38.66
# pinball loss for q50 = 39.66
# pinball loss for q60 = 38.44
# pinball loss for q70 = 34.87
# pinball loss for q80 = 28.63
# pinball loss for q90 = 18.77
# pinball loss for q10 = 20.01
# pinball loss for q20 = 29.93
# pinball loss for q30 = 36.03
# pinball loss for q40 = 39.41
# pinball loss for q50 = 40.36
# pinball loss for q60 = 39.09
# pinball loss for q70 = 35.47
# pinball loss for q80 = 29.02
# pinball loss for q90 = 18.84
# pinball loss for q10 = 19.55
# pinball loss for q20 = 29.50
# pinball loss for q30 = 35.68
# pinball loss for q40 = 39.26
# pinball loss for q50 = 40.46
# pinball loss for q60 = 39.23
# pinball loss for q70 = 35.65
# pinball loss for q80 = 29.24
# pinball loss for q90 = 18.98
# pinball loss for q10 = 19.20
# pinball loss for q20 = 28.86
# pinball loss for q30 = 34.97
# pinball loss for q40 = 38.60
# pinball loss for q50 = 39.67
# pinball loss for q60 = 38.40
# pinball loss for q70 = 34.85
# pinball loss for q80 = 28.56
# pinball loss for q90 = 18.50
# pinball loss for q10 = 19.06
# pinball loss for q20 = 28.43
# pinball loss for q30 = 34.31
# pinball loss for q40 = 37.68
# pinball loss for q50 = 38.81
# pinball loss for q60 = 37.63
# pinball loss for q70 = 34.07
# pinball loss for q80 = 27.83
# pinball loss for q90 = 17.99
# pinball loss for q10 = 19.34
# pinball loss for q20 = 28.79
# pinball loss for q30 = 34.40
# pinball loss for q40 = 37.45
# pinball loss for q50 = 38.33
# pinball loss for q60 = 37.10
# pinball loss for q70 = 33.46
# pinball loss for q80 = 27.34
# pinball loss for q90 = 17.67
# pinball loss for q10 = 19.68
# pinball loss for q20 = 29.07
# pinball loss for q30 = 34.70
# pinball loss for q40 = 37.66
# pinball loss for q50 = 38.37
# pinball loss for q60 = 36.92
# pinball loss for q70 = 33.25
# pinball loss for q80 = 27.08
# pinball loss for q90 = 17.53
# pinball loss for q10 = 20.06
# pinball loss for q20 = 29.66
# pinball loss for q30 = 35.32
# pinball loss for q40 = 38.14
# pinball loss for q50 = 38.70
# pinball loss for q60 = 37.19
# pinball loss for q70 = 33.44
# pinball loss for q80 = 27.25
# pinball loss for q90 = 17.86
# pinball loss for q10 = 19.89
# pinball loss for q20 = 29.62
# pinball loss for q30 = 35.47
# pinball loss for q40 = 38.52
# pinball loss for q50 = 39.21
# pinball loss for q60 = 37.73
# pinball loss for q70 = 34.19
# pinball loss for q80 = 28.13
# pinball loss for q90 = 18.67
# pinball loss for q10 = 19.93
# pinball loss for q20 = 29.55
# pinball loss for q30 = 35.52
# pinball loss for q40 = 38.73
# pinball loss for q50 = 39.65
# pinball loss for q60 = 38.39
# pinball loss for q70 = 34.97
# pinball loss for q80 = 28.87
# pinball loss for q90 = 19.10
# pinball loss for q10 = 19.79
# pinball loss for q20 = 29.64
# pinball loss for q30 = 35.64
# pinball loss for q40 = 38.95
# pinball loss for q50 = 39.98
# pinball loss for q60 = 38.89
# pinball loss for q70 = 35.49
# pinball loss for q80 = 29.38
# pinball loss for q90 = 19.46
# pinball loss for q10 = 20.33
# pinball loss for q20 = 30.53
# pinball loss for q30 = 36.73
# pinball loss for q40 = 40.17
# pinball loss for q50 = 41.30
# pinball loss for q60 = 40.03
# pinball loss for q70 = 36.39
# pinball loss for q80 = 30.00
# pinball loss for q90 = 19.90
# pinball loss for q10 = 20.52
# pinball loss for q20 = 30.78
# pinball loss for q30 = 37.25
# pinball loss for q40 = 40.80
# pinball loss for q50 = 41.83
# pinball loss for q60 = 40.55
# pinball loss for q70 = 36.91
# pinball loss for q80 = 30.48
# pinball loss for q90 = 20.22
# pinball loss for q10 = 20.98
# pinball loss for q20 = 31.63
# pinball loss for q30 = 37.98
# pinball loss for q40 = 41.54
# pinball loss for q50 = 42.62
# pinball loss for q60 = 41.31
# pinball loss for q70 = 37.53
# pinball loss for q80 = 31.00
# pinball loss for q90 = 20.42
# pinball loss for q10 = 20.75
# pinball loss for q20 = 31.28
# pinball loss for q30 = 37.75
# pinball loss for q40 = 41.45
# pinball loss for q50 = 42.69
# pinball loss for q60 = 41.52
# pinball loss for q70 = 37.87
# pinball loss for q80 = 31.34
# pinball loss for q90 = 20.56
# pinball loss for q10 = 20.40
# pinball loss for q20 = 30.54
# pinball loss for q30 = 36.93
# pinball loss for q40 = 40.66
# pinball loss for q50 = 41.95
# pinball loss for q60 = 40.83
# pinball loss for q70 = 37.23
# pinball loss for q80 = 30.73
# pinball loss for q90 = 20.14
# pinball loss for q10 = 20.27
# pinball loss for q20 = 30.08
# pinball loss for q30 = 36.26
# pinball loss for q40 = 39.77
# pinball loss for q50 = 40.95
# pinball loss for q60 = 39.73
# pinball loss for q70 = 36.12
# pinball loss for q80 = 29.68
# pinball loss for q90 = 19.35
# pinball loss for q10 = 20.44
# pinball loss for q20 = 30.09
# pinball loss for q30 = 35.92
# pinball loss for q40 = 39.18
# pinball loss for q50 = 40.25
# pinball loss for q60 = 38.94
# pinball loss for q70 = 35.30
# pinball loss for q80 = 29.03
# pinball loss for q90 = 18.98
# pinball loss for q10 = 20.67
# pinball loss for q20 = 30.25
# pinball loss for q30 = 36.05
# pinball loss for q40 = 39.25
# pinball loss for q50 = 40.10
# pinball loss for q60 = 38.82
# pinball loss for q70 = 35.13
# pinball loss for q80 = 28.69
# pinball loss for q90 = 18.69
# pinball loss for q10 = 20.92
# pinball loss for q20 = 30.70
# pinball loss for q30 = 36.56
# pinball loss for q40 = 39.70
# pinball loss for q50 = 40.34
# pinball loss for q60 = 38.80
# pinball loss for q70 = 35.11
# pinball loss for q80 = 28.92
# pinball loss for q90 = 19.05
# pinball loss for q10 = 20.67
# pinball loss for q20 = 30.55
# pinball loss for q30 = 36.53
# pinball loss for q40 = 39.71
# pinball loss for q50 = 40.59
# pinball loss for q60 = 39.22
# pinball loss for q70 = 35.50
# pinball loss for q80 = 29.22
# pinball loss for q90 = 19.39
# pinball loss for q10 = 20.61
# pinball loss for q20 = 30.59
# pinball loss for q30 = 36.67
# pinball loss for q40 = 39.94
# pinball loss for q50 = 40.94
# pinball loss for q60 = 39.75
# pinball loss for q70 = 36.17
# pinball loss for q80 = 29.94
# pinball loss for q90 = 19.84
# pinball loss for q10 = 20.76
# pinball loss for q20 = 30.82
# pinball loss for q30 = 36.95
# pinball loss for q40 = 40.40
# pinball loss for q50 = 41.53
# pinball loss for q60 = 40.40
# pinball loss for q70 = 36.87
# pinball loss for q80 = 30.58
# pinball loss for q90 = 20.34
# pinball loss for q10 = 21.31
# pinball loss for q20 = 31.71
# pinball loss for q30 = 38.09
# pinball loss for q40 = 41.74
# pinball loss for q50 = 42.93
# pinball loss for q60 = 41.72
# pinball loss for q70 = 38.09
# pinball loss for q80 = 31.60
# pinball loss for q90 = 21.10
# pinball loss for q10 = 21.52
# pinball loss for q20 = 32.19
# pinball loss for q30 = 38.75
# pinball loss for q40 = 42.42
# pinball loss for q50 = 43.58
# pinball loss for q60 = 42.35
# pinball loss for q70 = 38.62
# pinball loss for q80 = 32.02
# pinball loss for q90 = 21.42
# pinball loss for q10 = 22.03
# pinball loss for q20 = 32.77
# pinball loss for q30 = 39.26
# pinball loss for q40 = 42.92
# pinball loss for q50 = 44.13
# pinball loss for q60 = 42.97
# pinball loss for q70 = 39.25
# pinball loss for q80 = 32.56
# pinball loss for q90 = 21.73
